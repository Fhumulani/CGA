# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
data = pd.read_csv("data-values.txt",sep=',',names=['inj','cen','ext','rf','cur','fitness','gen'])

# %%
fig, ax = plt.subplots(2,2)
fig.set_figheight(10)
fig.set_figwidth(15)
ax[0,0].scatter(range(len(data.cur[:20])),data.inj[:20])
ax[0,0].scatter(range(len(params.inj[:336])),params.inj[:336])
#ax[0,0].scatter(range(len(data.cur[20:35])),data.inj[20:35],color='red')
#ax[0,0].scatter(range(len(data.cur[35:])),data.inj[35:],color='green')
ax[0,0].set_ylim(700,1000)


ax[1,0].scatter(range(len(data.cur[:20])),data.ext[:20])
ax[1,0].scatter(range(len(data.cur[20:35])),data.ext[20:35],color='red')
ax[1,0].scatter(range(len(params.ext[:336])),params.ext[:336])
ax[1,0].scatter(range(len(data.cur[35:])),data.ext[35:],color='green')
ax[1,0].set_ylim(700,1000)

ax[0,1].scatter(range(len(data.cur[:20])),data.cen[:20])
ax[0,1].scatter(range(len(data.cur[20:35])),data.cen[20:35],color='red')
ax[0,1].scatter(range(len(params.inj[:336])),params.cen[:336])
ax[0,1].scatter(range(len(data.cur[35:])),data.cen[35:],color='green')
ax[0,1].set_ylim(-200,-150)


ax[1,1].scatter(time,data.rf[:20])
#ax[1,1].scatter(time,data.rf[20:35],color='red')
#ax[1,1].scatter(time,params.rf[:336])
ax[1,1].scatter(time,data.rf[35:],color='green')
ax[1,1].set_ylim(10,40)
ax[1,1].set_ylabel("RF [W]")
ax[1,1].set_xlabel("Time [minutes]")
# Out:
# Text(0.5, 0, 'Time [minutes]')

# %%
params = pd.read_csv("params-values.txt",sep=',',names=['inj','cen','ext','rf'])

# %%
len(params)
# Out:
# 939

# %%
((16*20)+16)+((16*14)+16)+((16*20)+16)
# Out:
# 912

# %%
939-912
# Out:
# 27

# %%
plt.scatter(range(len(params.inj[:336])),params.inj[:336])

# %%
time = np.linspace(1,29.8,20)

# %%
time
# Out:
# array([ 1.        ,  2.51578947,  4.03157895,  5.54736842,  7.06315789,
#         8.57894737, 10.09473684, 11.61052632, 13.12631579, 14.64210526,
#        16.15789474, 17.67368421, 19.18947368, 20.70526316, 22.22105263,
#        23.73684211, 25.25263158, 26.76842105, 28.28421053, 29.8       ])

# %%
len(time)
# Out:
# 20
